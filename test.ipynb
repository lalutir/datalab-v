# %%
import xarray as xr
import pandas as pd

ds = xr.open_zarr("data/processed/era5_subset.zarr")
df = ds.to_dataframe().reset_index()
df
# Out:
#              time  latitude  longitude         d2m         t2m  number   step  \
# 0      2018-01-01      15.0      25.00  268.749603  285.378052       0 0 days
# 1      2018-01-01      15.0      25.25  268.839935  285.210907       0 0 days
# 2      2018-01-01      15.0      25.50  269.188904  285.268829       0 0 days
# 3      2018-01-01      15.0      25.75  269.337189  285.344116       0 0 days
# 4      2018-01-01      15.0      26.00  269.188080  285.772095       0 0 days
# ...           ...       ...        ...         ...         ...     ...    ...
# 590485 2018-03-31      -5.0      44.00  296.673676  301.147888       0 0 days
# 590486 2018-03-31      -5.0      44.25  296.626556  301.215271       0 0 days
# 590487 2018-03-31      -5.0      44.50  296.590912  301.314301       0 0 days
# 590488 2018-03-31      -5.0      44.75  296.560303  301.387482       0 0 days
# 590489 2018-03-31      -5.0      45.00  296.566895  301.419128       0 0 days
#
#         surface
# ...
